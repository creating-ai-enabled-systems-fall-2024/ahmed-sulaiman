# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

import numpy as np
import matplotlib.pyplot as plt
from modules.extraction.embedding import EmbeddingExtractor
from modules.retrieval.index import Indexer
from modules.retrieval.search import Searcher
from pipeline import Pipeline
import torch
from PIL import Image
from facenet_pytorch import InceptionResnetV1
import faiss
import numpy as np
from torchvision import transforms
from scipy.spatial.distance import cosine
import random

# %%
pipeline_vggface = Pipeline(model='vggface2', device='cpu') 
pipeline_casia = Pipeline(model='casia-webface', device='cpu')

probe_directory = '../datasets/multi_image_identities/probe'
gallery_directory = '../datasets/multi_image_identities/multi_image_gallery'

# %%
pipeline_vggface.precompute(gallery_directory)
pipeline_vggface.save_embeddings('../storage/catalog/faiss_vggface.bin')

pipeline_casia.precompute(gallery_directory)
pipeline_casia.save_embeddings('../storage/catalog/faiss_casia.bin')
# Out:
# Number of embeddings to add: 2265
# Number of embeddings added to FAISS: 2265
# Number of gallery filenames: 2265
# Number of embeddings to add: 2265
# Number of embeddings added to FAISS: 2265
# Number of gallery filenames: 2265

# %%
# Dictionaries to store the results
vggface_results = {}
casia_results = {}

# Traverse the probe directory to get all probe images
for root, dirs, files in os.walk(probe_directory):
    for filename in files:
        if filename.endswith(('.jpg', '.png')):
            image_path = os.path.join(root, filename)
            image = Image.open(image_path)

            # Encode the image into an embedding
            probe_embedding_vggface = pipeline_vggface.encode(image)
            probe_embedding_casia = pipeline_casia.encode(image)

            # Perform FAISS search using the embeddings
            neighbors_vggface = pipeline_vggface.search_gallery(probe_embedding_vggface, k=5)
            neighbors_casia = pipeline_casia.search_gallery(probe_embedding_casia, k=5)

            # Store the results
            vggface_results[filename] = neighbors_vggface
            casia_results[filename] = neighbors_casia

# Print example results
print("VGGFace Results for Probe Images:", vggface_results)
print("Casia-Webface Results for Probe Images:", casia_results)
# Out:
# VGGFace Results for Probe Images: {'Paul_McNulty_0002.jpg': [(('Paul_McNulty', 'Paul_McNulty_0001.jpg'), 0.41251633), (('Sean_Astin', 'Sean_Astin_0002.jpg'), 0.7705041), (('Mike_Babcock', 'Mike_Babcock_0001.jpg'), 0.8171375), (('Bill_Frist', 'Bill_Frist_0006.jpg'), 0.9046857), (('Ann_Veneman', 'Ann_Veneman_0009.jpg'), 0.9184737)], 'Mary-Kate_Olsen_0002.jpg': [(('Mary-Kate_Olsen', 'Mary-Kate_Olsen_0001.jpg'), 0.42585242), (('Mary-Kate_Olsen', 'Mary-Kate_Olsen_0002.jpg'), 0.65783614), (('Evan_Rachel_Wood', 'Evan_Rachel_Wood_0001.jpg'), 0.78179204), (('Sarah_Jessica_Parker', 'Sarah_Jessica_Parker_0003.jpg'), 0.80074483), (('Mary_Landrieu', 'Mary_Landrieu_0002.jpg'), 0.8268363)], 'Phil_Mickelson_0002.jpg': [(('Phil_Mickelson', 'Phil_Mickelson_0001.jpg'), 0.46805406), (('Yevgeny_Kafelnikov', 'Yevgeny_Kafelnikov_0001.jpg'), 0.7576541), (('Jim_Furyk', 'Jim_Furyk_0004.jpg'), 0.77930224), (('Fred_Funk', 'Fred_Funk_0001.jpg'), 0.81262153), (('Larry_Coker', 'Larry_Coker_0002.jpg'), 0.8312421)], 'Jim_Edmonds_0002.jpg': [(('Robby_Ginepri', 'Robby_Ginepri_0001.jpg'), 0.8374168), (('Leland_Chapman', 'Leland_Chapman_0001.jpg'), 0.9192066), (('Jean-Sebastien_Giguere', 'Jean-Sebastien_Giguere_0001.jpg'), 0.9518498), (('Augustin_Calleri', 'Augustin_Calleri_0002.jpg'), 0.9859556), (('Mikhail_Youzhny', 'Mikhail_Youzhny_0001.jpg'), 0.99981093)], 'Martina_McBride_0002.jpg': [(('Martina_McBride', 'Martina_McBride_0004.jpg'), 0.82258284), (('Martina_McBride', 'Martina_McBride_0003.jpg'), 0.95170903), (('Julianne_Moore', 'Julianne_Moore_0007.jpg'), 1.0217566), (('Heidi_Fleiss', 'Heidi_Fleiss_0003.jpg'), 1.0333401), (('Queen_Beatrix', 'Queen_Beatrix_0003.jpg'), 1.0744956)], 'Jose_Theodore_0002.jpg': [(('Luis_Horna', 'Luis_Horna_0001.jpg'), 0.9401618), (('Augustin_Calleri', 'Augustin_Calleri_0002.jpg'), 0.9999901), (('Jose_Theodore', 'Jose_Theodore_0001.jpg'), 1.0195012), (('Augustin_Calleri', 'Augustin_Calleri_0003.jpg'), 1.0531945), (('Janet_Thorpe', 'Janet_Thorpe_0001.jpg'), 1.1476052)], 'Heidi_Fleiss_0002.jpg': [(('Elsa_Zylberstein', 'Elsa_Zylberstein_0005.jpg'), 0.86281097), (('Elsa_Zylberstein', 'Elsa_Zylberstein_0003.jpg'), 0.86291254), (('Elsa_Zylberstein', 'Elsa_Zylberstein_0004.jpg'), 0.9034677), (('Heidi_Fleiss', 'Heidi_Fleiss_0002.jpg'), 0.9148209), (('Heidi_Fleiss', 'Heidi_Fleiss_0001.jpg'), 0.9243596)], 'Paul_ONeill_0002.jpg': [(('Paul_ONeill', 'Paul_ONeill_0001.jpg'), 0.28374505), (('Paul_ONeill', 'Paul_ONeill_0002.jpg'), 0.4471554), (('Paul_ONeill', 'Paul_ONeill_0005.jpg'), 0.46156406), (('Paul_ONeill', 'Paul_ONeill_0006.jpg'), 0.53254163), (('Paul_ONeill', 'Paul_ONeill_0007.jpg'), 0.6955016)], 'Tony_Curtis_0002.jpg': [(('Tony_Curtis', 'Tony_Curtis_0001.jpg'), 0.49742925), (('Colin_Powell', 'Colin_Powell_0007.jpg'), 0.8437027), (('Colin_Powell', 'Colin_Powell_0001.jpg'), 0.8498828), (('John_Manley', 'John_Manley_0003.jpg'), 0.86540836), (('Dennis_Erickson', 'Dennis_Erickson_0001.jpg'), 0.9036673)], 'Gro_Harlem_Brundtland_0002.jpg': [(('Gro_Harlem_Brundtland', 'Gro_Harlem_Brundtland_0001.jpg'), 0.47483334), (('Ann_Veneman', 'Ann_Veneman_0006.jpg'), 0.8972437), (('Ann_Veneman', 'Ann_Veneman_0010.jpg'), 0.9352708), (('Ann_Veneman', 'Ann_Veneman_0004.jpg'), 1.0185618), (('Lynne_Cheney', 'Lynne_Cheney_0001.jpg'), 1.024478)], 'Angela_Lansbury_0002.jpg': [(('Angela_Lansbury', 'Angela_Lansbury_0001.jpg'), 0.6457534), (('Jean_Brumley', 'Jean_Brumley_0001.jpg'), 1.0067744), (('Melanie_Griffith', 'Melanie_Griffith_0002.jpg'), 1.0140741), (('Lynne_Cheney', 'Lynne_Cheney_0002.jpg'), 1.0707843), (('Sheila_Copps', 'Sheila_Copps_0002.jpg'), 1.0746924)], 'Cathy_Freeman_0002.jpg': [(('Cathy_Freeman', 'Cathy_Freeman_0001.jpg'), 0.48678902), (('Kelli_White', 'Kelli_White_0001.jpg'), 0.6694037), (('Patty_Schnyder', 'Patty_Schnyder_0003.jpg'), 0.6852926), (('Lindsay_Davenport', 'Lindsay_Davenport_0006.jpg'), 0.69174397), (('Chanda_Rubin', 'Chanda_Rubin_0004.jpg'), 0.73122084)], 'Christine_Ebersole_0002.jpg': [(('Meryl_Streep', 'Meryl_Streep_0002.jpg'), 0.96937 ...
# Casia-Webface Results for Probe Images: {'Paul_McNulty_0002.jpg': [(('Paul_McNulty', 'Paul_McNulty_0001.jpg'), 0.439106), (('Anna_Kournikova', 'Anna_Kournikova_0009.jpg'), 0.5989881), (('Aron_Ralston', 'Aron_Ralston_0001.jpg'), 0.60525495), (('Hamzah_Haz', 'Hamzah_Haz_0001.jpg'), 0.62483317), (('Christine_Gregoire', 'Christine_Gregoire_0003.jpg'), 0.6663005)], 'Mary-Kate_Olsen_0002.jpg': [(('Celine_Dion', 'Celine_Dion_0003.jpg'), 0.45158628), (('Jennifer_Aniston', 'Jennifer_Aniston_0005.jpg'), 0.49447697), (('Jennifer_Aniston', 'Jennifer_Aniston_0009.jpg'), 0.5157258), (('Jodie_Foster', 'Jodie_Foster_0002.jpg'), 0.52289337), (('Jennifer_Aniston', 'Jennifer_Aniston_0004.jpg'), 0.55146617)], 'Phil_Mickelson_0002.jpg': [(('Jim_Furyk', 'Jim_Furyk_0004.jpg'), 0.83019364), (('Jim_Furyk', 'Jim_Furyk_0005.jpg'), 0.83790874), (('Jack_Straw', 'Jack_Straw_0003.jpg'), 0.9276068), (('Roy_Moore', 'Roy_Moore_0002.jpg'), 0.96703464), (('Tom_Glavine', 'Tom_Glavine_0001.jpg'), 0.9686689)], 'Jim_Edmonds_0002.jpg': [(('Geoff_Hoon', 'Geoff_Hoon_0004.jpg'), 0.4627957), (('Arnaud_Clement', 'Arnaud_Clement_0001.jpg'), 0.50531566), (('Jean-David_Levitte', 'Jean-David_Levitte_0001.jpg'), 0.51957643), (('John_Allen_Muhammad', 'John_Allen_Muhammad_0005.jpg'), 0.5312353), (('Jonathan_Edwards', 'Jonathan_Edwards_0004.jpg'), 0.5316988)], 'Martina_McBride_0002.jpg': [(('Tracee_Ellis_Ross', 'Tracee_Ellis_Ross_0001.jpg'), 0.5377309), (('Lisa_Ling', 'Lisa_Ling_0001.jpg'), 0.5707448), (('Beth_Jones', 'Beth_Jones_0001.jpg'), 0.6146324), (('Gianna_Angelopoulos-Daskalaki', 'Gianna_Angelopoulos-Daskalaki_0001.jpg'), 0.6176697), (('Katie_Harman', 'Katie_Harman_0002.jpg'), 0.6213512)], 'Jose_Theodore_0002.jpg': [(('Manuel_Poggiali', 'Manuel_Poggiali_0001.jpg'), 0.4065159), (('Nestor_Kirchner', 'Nestor_Kirchner_0008.jpg'), 0.454588), (('Elvis_Presley', 'Elvis_Presley_0001.jpg'), 0.45659453), (('Taufik_Hidayat', 'Taufik_Hidayat_0001.jpg'), 0.4672968), (('Charlotte_Rampling', 'Charlotte_Rampling_0001.jpg'), 0.47525856)], 'Heidi_Fleiss_0002.jpg': [(('Amelia_Vega', 'Amelia_Vega_0002.jpg'), 0.5507392), (('Lisa_Ling', 'Lisa_Ling_0001.jpg'), 0.5555408), (('Dolma_Tsering', 'Dolma_Tsering_0001.jpg'), 0.5814173), (('Intisar_Ajouri', 'Intisar_Ajouri_0002.jpg'), 0.6217896), (('Elsa_Zylberstein', 'Elsa_Zylberstein_0003.jpg'), 0.643692)], 'Paul_ONeill_0002.jpg': [(('Benjamin_Netanyahu', 'Benjamin_Netanyahu_0003.jpg'), 0.42247605), (('Paul_ONeill', 'Paul_ONeill_0001.jpg'), 0.42859662), (('Paul_ONeill', 'Paul_ONeill_0005.jpg'), 0.54954505), (('Arye_Mekel', 'Arye_Mekel_0001.jpg'), 0.5584565), (('Igor_Ivanov', 'Igor_Ivanov_0008.jpg'), 0.56929266)], 'Tony_Curtis_0002.jpg': [(('George_Pataki', 'George_Pataki_0001.jpg'), 0.35532004), (('Ernie_Eves', 'Ernie_Eves_0001.jpg'), 0.4450136), (('Tony_Curtis', 'Tony_Curtis_0001.jpg'), 0.46845967), (('Sam_Bith', 'Sam_Bith_0002.jpg'), 0.50946426), (('Jackie_Chan', 'Jackie_Chan_0006.jpg'), 0.5130565)], 'Gro_Harlem_Brundtland_0002.jpg': [(('Gro_Harlem_Brundtland', 'Gro_Harlem_Brundtland_0001.jpg'), 0.7301414), (('John_Manley', 'John_Manley_0002.jpg'), 0.84155464), (('David_Trimble', 'David_Trimble_0001.jpg'), 0.90579987), (('Queen_Beatrix', 'Queen_Beatrix_0001.jpg'), 0.90844417), (('Diane_Green', 'Diane_Green_0001.jpg'), 0.91730225)], 'Angela_Lansbury_0002.jpg': [(('Gro_Harlem_Brundtland', 'Gro_Harlem_Brundtland_0001.jpg'), 0.5405705), (('Carlo_Ancelotti', 'Carlo_Ancelotti_0002.jpg'), 0.54836595), (('David_Nalbandian', 'David_Nalbandian_0009.jpg'), 0.5659887), (('Ann_Veneman', 'Ann_Veneman_0005.jpg'), 0.6333413), (('Donna_Shalala', 'Donna_Shalala_0001.jpg'), 0.69585866)], 'Cathy_Freeman_0002.jpg': [(('Juan_Pablo_Montoya', 'Juan_Pablo_Montoya_0006.jpg'), 0.399538), (('Bob_Hope', 'Bob_Hope_0003.jpg'), 0.4082963), (('David_Heymann', 'David_Heymann_0002.jpg'), 0.43658304), (('John_Allen_Muhammad', 'John_Allen_Muhammad_0009.jpg'), 0.43924797), (('John_F_Kennedy_Jr', 'John_F_Kennedy_Jr_0001.jpg'), 0.45855856)], 'Christine_Ebersole_0002.jpg': [(('Gregg_Popovi ...

# %%
def add_noise(image, noise_level=0.1):
    if not isinstance(image, torch.Tensor):
        raise ValueError("Image must be a preprocessed tensor.")
    
    # Generate random noise
    noise = torch.randn_like(image) * noise_level
    noisy_image = image + noise
    return torch.clamp(noisy_image, -1, 1)

# %%
preprocess = transforms.Compose([
    transforms.Resize((160, 160)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# %%
noisy_vggface_results = {}
noisy_casia_results = {}

# Traverse the probe directory again to apply noise to each image
for root, dirs, files in os.walk(probe_directory):
    for filename in files:
        if filename.endswith(('.jpg', '.png')):
            image_path = os.path.join(root, filename)
            image = Image.open(image_path)

            # Preprocess the image into a tensor
            image_tensor = preprocess(image)

            # Add noise to the image tensor
            noisy_image = add_noise(image_tensor)

            # Encode the noisy image into an embedding
            noisy_embedding_vggface = pipeline_vggface.encode(noisy_image)
            noisy_embedding_casia = pipeline_casia.encode(noisy_image)

            # Perform FAISS search using the noisy embeddings
            noisy_neighbors_vggface = pipeline_vggface.search_gallery(noisy_embedding_vggface, k=5)
            noisy_neighbors_casia = pipeline_casia.search_gallery(noisy_embedding_casia, k=5)

            # Store the noisy results
            noisy_vggface_results[filename] = noisy_neighbors_vggface
            noisy_casia_results[filename] = noisy_neighbors_casia

# Print example noisy results
print("Noisy VGGFace Results for Probe Images:", noisy_vggface_results)
print("Noisy Casia-Webface Results for Probe Images:", noisy_casia_results)
# Out:
# Noisy VGGFace Results for Probe Images: {'Paul_McNulty_0002.jpg': [(('Paul_McNulty', 'Paul_McNulty_0001.jpg'), 0.456427), (('Sean_Astin', 'Sean_Astin_0002.jpg'), 0.76604366), (('Mike_Babcock', 'Mike_Babcock_0001.jpg'), 0.7682097), (('Jan_Ullrich', 'Jan_Ullrich_0003.jpg'), 0.8840013), (('Jan_Ullrich', 'Jan_Ullrich_0002.jpg'), 0.89941335)], 'Mary-Kate_Olsen_0002.jpg': [(('Mary-Kate_Olsen', 'Mary-Kate_Olsen_0001.jpg'), 0.53471226), (('Evan_Rachel_Wood', 'Evan_Rachel_Wood_0001.jpg'), 0.72461927), (('Mary-Kate_Olsen', 'Mary-Kate_Olsen_0002.jpg'), 0.7346194), (('Sarah_Jessica_Parker', 'Sarah_Jessica_Parker_0003.jpg'), 0.89871967), (('Blythe_Danner', 'Blythe_Danner_0001.jpg'), 0.9238323)], 'Phil_Mickelson_0002.jpg': [(('Phil_Mickelson', 'Phil_Mickelson_0001.jpg'), 0.6527641), (('Yevgeny_Kafelnikov', 'Yevgeny_Kafelnikov_0001.jpg'), 0.7451931), (('David_Nalbandian', 'David_Nalbandian_0007.jpg'), 0.79500806), (('Larry_Coker', 'Larry_Coker_0002.jpg'), 0.8002092), (('Fred_Funk', 'Fred_Funk_0001.jpg'), 0.8363459)], 'Jim_Edmonds_0002.jpg': [(('Robby_Ginepri', 'Robby_Ginepri_0001.jpg'), 0.84026587), (('Leland_Chapman', 'Leland_Chapman_0001.jpg'), 0.9488877), (('Jean-Sebastien_Giguere', 'Jean-Sebastien_Giguere_0001.jpg'), 0.9762633), (('Tom_Cruise', 'Tom_Cruise_0006.jpg'), 0.9839526), (('John_Ruiz', 'John_Ruiz_0001.jpg'), 1.0595785)], 'Martina_McBride_0002.jpg': [(('Martina_McBride', 'Martina_McBride_0004.jpg'), 0.7205317), (('Martina_McBride', 'Martina_McBride_0003.jpg'), 0.81527376), (('Julianne_Moore', 'Julianne_Moore_0007.jpg'), 0.9283527), (('Heidi_Fleiss', 'Heidi_Fleiss_0003.jpg'), 0.9879736), (('Queen_Beatrix', 'Queen_Beatrix_0003.jpg'), 1.0155329)], 'Jose_Theodore_0002.jpg': [(('Luis_Horna', 'Luis_Horna_0001.jpg'), 0.9262222), (('Augustin_Calleri', 'Augustin_Calleri_0002.jpg'), 1.0373547), (('Augustin_Calleri', 'Augustin_Calleri_0003.jpg'), 1.1461041), (('Michael_Ballack', 'Michael_Ballack_0002.jpg'), 1.152108), (('Charles_Mathews', 'Charles_Mathews_0001.jpg'), 1.1814148)], 'Heidi_Fleiss_0002.jpg': [(('Heidi_Fleiss', 'Heidi_Fleiss_0002.jpg'), 0.83516705), (('Elsa_Zylberstein', 'Elsa_Zylberstein_0005.jpg'), 0.918942), (('Elsa_Zylberstein', 'Elsa_Zylberstein_0003.jpg'), 0.94661415), (('Heidi_Fleiss', 'Heidi_Fleiss_0001.jpg'), 0.95752597), (('Elsa_Zylberstein', 'Elsa_Zylberstein_0004.jpg'), 1.0353415)], 'Paul_ONeill_0002.jpg': [(('Paul_ONeill', 'Paul_ONeill_0001.jpg'), 0.32489812), (('Paul_ONeill', 'Paul_ONeill_0002.jpg'), 0.4909058), (('Paul_ONeill', 'Paul_ONeill_0005.jpg'), 0.52437353), (('Paul_ONeill', 'Paul_ONeill_0006.jpg'), 0.5541376), (('Paul_ONeill', 'Paul_ONeill_0003.jpg'), 0.68897223)], 'Tony_Curtis_0002.jpg': [(('Tony_Curtis', 'Tony_Curtis_0001.jpg'), 0.5645567), (('Richard_Gephardt', 'Richard_Gephardt_0010.jpg'), 0.7836356), (('Richard_Gephardt', 'Richard_Gephardt_0009.jpg'), 0.80638945), (('Richard_Gephardt', 'Richard_Gephardt_0004.jpg'), 0.82593656), (('Colin_Powell', 'Colin_Powell_0001.jpg'), 0.8623282)], 'Gro_Harlem_Brundtland_0002.jpg': [(('Gro_Harlem_Brundtland', 'Gro_Harlem_Brundtland_0001.jpg'), 0.41678786), (('Ann_Veneman', 'Ann_Veneman_0006.jpg'), 0.920083), (('Ann_Veneman', 'Ann_Veneman_0010.jpg'), 0.9925099), (('Ann_Veneman', 'Ann_Veneman_0004.jpg'), 1.0373127), (('Martha_Burk', 'Martha_Burk_0001.jpg'), 1.041631)], 'Angela_Lansbury_0002.jpg': [(('Angela_Lansbury', 'Angela_Lansbury_0001.jpg'), 0.6672163), (('Jean_Brumley', 'Jean_Brumley_0001.jpg'), 0.9833672), (('Sheila_Copps', 'Sheila_Copps_0002.jpg'), 1.0780025), (('Gro_Harlem_Brundtland', 'Gro_Harlem_Brundtland_0001.jpg'), 1.1158409), (('Melanie_Griffith', 'Melanie_Griffith_0002.jpg'), 1.1514387)], 'Cathy_Freeman_0002.jpg': [(('Cathy_Freeman', 'Cathy_Freeman_0001.jpg'), 0.5481826), (('Kelli_White', 'Kelli_White_0001.jpg'), 0.6690946), (('Patty_Schnyder', 'Patty_Schnyder_0002.jpg'), 0.7516811), (('Chanda_Rubin', 'Chanda_Rubin_0004.jpg'), 0.752961), (('Patty_Schnyder', 'Patty_Schnyder_0003.jpg'), 0.75704336)], 'Christine_Ebersole_0002.jpg': [(('Christine_Ebersole' ...
# Noisy Casia-Webface Results for Probe Images: {'Paul_McNulty_0002.jpg': [(('Julie_Gerberding', 'Julie_Gerberding_0004.jpg'), 0.5450883), (('Hannah_Stockbauer', 'Hannah_Stockbauer_0001.jpg'), 0.55080664), (('Anna_Kournikova', 'Anna_Kournikova_0009.jpg'), 0.57467926), (('Christine_Gregoire', 'Christine_Gregoire_0003.jpg'), 0.58925724), (('Hitomi_Soga', 'Hitomi_Soga_0004.jpg'), 0.60219276)], 'Mary-Kate_Olsen_0002.jpg': [(('Ozzy_Osbourne', 'Ozzy_Osbourne_0002.jpg'), 0.64216727), (('Jennifer_Lopez', 'Jennifer_Lopez_0003.jpg'), 0.6835137), (('Monica_Bellucci', 'Monica_Bellucci_0003.jpg'), 0.7090263), (('Mariah_Carey', 'Mariah_Carey_0003.jpg'), 0.7186134), (('Alexandra_Vodjanikova', 'Alexandra_Vodjanikova_0001.jpg'), 0.72943336)], 'Phil_Mickelson_0002.jpg': [(('Tom_Glavine', 'Tom_Glavine_0001.jpg'), 0.974122), (('Jim_Furyk', 'Jim_Furyk_0005.jpg'), 0.98613536), (('Jack_Straw', 'Jack_Straw_0003.jpg'), 1.000464), (('Roy_Moore', 'Roy_Moore_0002.jpg'), 1.0385458), (('Thierry_Falise', 'Thierry_Falise_0002.jpg'), 1.0422907)], 'Jim_Edmonds_0002.jpg': [(('Alec_Baldwin', 'Alec_Baldwin_0001.jpg'), 0.5853395), (('Inocencio_Arias', 'Inocencio_Arias_0001.jpg'), 0.59151006), (('Tom_Daschle', 'Tom_Daschle_0005.jpg'), 0.5922401), (('Alejandro_Toledo', 'Alejandro_Toledo_0010.jpg'), 0.5971861), (('Tom_Daschle', 'Tom_Daschle_0003.jpg'), 0.6003285)], 'Martina_McBride_0002.jpg': [(('Beth_Jones', 'Beth_Jones_0001.jpg'), 0.51824945), (('Carson_Daly', 'Carson_Daly_0001.jpg'), 0.55521363), (('George_Robertson', 'George_Robertson_0001.jpg'), 0.5559231), (('Steve_Waugh', 'Steve_Waugh_0001.jpg'), 0.5583181), (('Alejandro_Toledo', 'Alejandro_Toledo_0005.jpg'), 0.56363726)], 'Jose_Theodore_0002.jpg': [(('Jackie_Chan', 'Jackie_Chan_0004.jpg'), 0.4882824), (('Alex_Penelas', 'Alex_Penelas_0001.jpg'), 0.4932999), (('Johnny_Unitas', 'Johnny_Unitas_0001.jpg'), 0.49611604), (('Robert_De_Niro', 'Robert_De_Niro_0001.jpg'), 0.52400327), (('Jose_Mourinho', 'Jose_Mourinho_0001.jpg'), 0.5299338)], 'Heidi_Fleiss_0002.jpg': [(('Ozzy_Osbourne', 'Ozzy_Osbourne_0001.jpg'), 0.63786465), (('Amelia_Vega', 'Amelia_Vega_0002.jpg'), 0.6533328), (('Hitomi_Soga', 'Hitomi_Soga_0004.jpg'), 0.657673), (('Ashanti', 'Ashanti_0001.jpg'), 0.6841928), (('Megawati_Sukarnoputri', 'Megawati_Sukarnoputri_0005.jpg'), 0.6864587)], 'Paul_ONeill_0002.jpg': [(('Benjamin_Netanyahu', 'Benjamin_Netanyahu_0003.jpg'), 0.5833086), (('Igor_Ivanov', 'Igor_Ivanov_0008.jpg'), 0.59547067), (('Pedro_Malan', 'Pedro_Malan_0003.jpg'), 0.5982523), (('Joseph_Estrada', 'Joseph_Estrada_0002.jpg'), 0.6060718), (('Paul_ONeill', 'Paul_ONeill_0001.jpg'), 0.62019956)], 'Tony_Curtis_0002.jpg': [(('Tony_Curtis', 'Tony_Curtis_0001.jpg'), 0.4998179), (('Sam_Bith', 'Sam_Bith_0001.jpg'), 0.50553274), (('Juan_Pablo_Montoya', 'Juan_Pablo_Montoya_0007.jpg'), 0.5404762), (('Sam_Bith', 'Sam_Bith_0002.jpg'), 0.5525963), (('Frank_Stallone', 'Frank_Stallone_0001.jpg'), 0.5547543)], 'Gro_Harlem_Brundtland_0002.jpg': [(('Gro_Harlem_Brundtland', 'Gro_Harlem_Brundtland_0001.jpg'), 0.6210103), (('Jimmy_Carter', 'Jimmy_Carter_0007.jpg'), 0.8361949), (('Michael_Chiklis', 'Michael_Chiklis_0004.jpg'), 0.8716044), (('Doris_Roberts', 'Doris_Roberts_0002.jpg'), 0.88444185), (('Boris_Yeltsin', 'Boris_Yeltsin_0001.jpg'), 0.888708)], 'Angela_Lansbury_0002.jpg': [(('Carlo_Ancelotti', 'Carlo_Ancelotti_0002.jpg'), 0.4959162), (('David_Nalbandian', 'David_Nalbandian_0009.jpg'), 0.5539998), (('Dick_Vermeil', 'Dick_Vermeil_0001.jpg'), 0.6388336), (('Sam_Bith', 'Sam_Bith_0001.jpg'), 0.66746986), (('Prince_Willem-Alexander', 'Prince_Willem-Alexander_0001.jpg'), 0.6876644)], 'Cathy_Freeman_0002.jpg': [(('Bob_Hope', 'Bob_Hope_0003.jpg'), 0.40748075), (('Alberto_Ruiz_Gallardon', 'Alberto_Ruiz_Gallardon_0001.jpg'), 0.41525805), (('Juan_Pablo_Montoya', 'Juan_Pablo_Montoya_0006.jpg'), 0.4520378), (('Mario_Kreutzberger', 'Mario_Kreutzberger_0001.jpg'), 0.49175543), (('John_Allen_Muhammad', 'John_Allen_Muhammad_0001.jpg'), 0.4943276)], 'Christine_Ebersole_0002.jpg': [(('Bar ...

# %%
def calculate_average_distance(results):
    avg_distances = {}
    for filename, neighbors in results.items():
        distances = [neighbor[1] for neighbor in neighbors]
        avg_distances[filename] = np.mean(distances)
    return avg_distances

# %%
vggface_avg_distances = calculate_average_distance(vggface_results)
casia_avg_distances = calculate_average_distance(casia_results)

noisy_vggface_avg_distances = calculate_average_distance(noisy_vggface_results)
noisy_casia_avg_distances = calculate_average_distance(noisy_casia_results)

# %%
filenames = list(vggface_avg_distances.keys())
vggface_distances = list(vggface_avg_distances.values())
casia_distances = list(casia_avg_distances.values())
noisy_vggface_distances = list(noisy_vggface_avg_distances.values())
noisy_casia_distances = list(noisy_casia_avg_distances.values())

# %%
sample_filenames = random.sample(filenames, 50)
vggface_sample = [vggface_avg_distances[f] for f in sample_filenames]
casia_sample = [casia_avg_distances[f] for f in sample_filenames]
noisy_vggface_sample = [noisy_vggface_avg_distances[f] for f in sample_filenames]
noisy_casia_sample = [noisy_casia_avg_distances[f] for f in sample_filenames]

plt.figure(figsize=(12, 6))
plt.plot(sample_filenames, vggface_sample, label='VGGFace2', marker='o')
plt.plot(sample_filenames, casia_sample, label='Casia-Webface', marker='o')
plt.plot(sample_filenames, noisy_vggface_sample, label='Noisy VGGFace2', linestyle='--', marker='x')
plt.plot(sample_filenames, noisy_casia_sample, label='Noisy Casia-Webface', linestyle='--', marker='x')
plt.xticks(rotation=90)
plt.legend()
plt.title('Average FAISS Distance Comparison for a Subsample of Probe Images')
plt.show()

# %% [markdown]
# 1. General Prediction Model Performance
# Looking at the plot, the performance of the two models, VGGFace2 and Casia-Webface, shows some distinct patterns:
#
# VGGFace2 (blue line) tends to have higher FAISS distances on average, indicating that its embeddings may be less tightly clustered in the gallery compared to Casia-Webface. However, VGGFace2 appears more consistent across probe images.
# Casia-Webface (orange line) has lower FAISS distances on average, meaning its embeddings are generally closer to their nearest neighbors. This suggests that Casia-Webface might create embeddings that are more tightly packed or more easily distinguishable within the gallery.
# Both models have instances where the distances spike, showing that for some images, the models struggle to find close matches, but Casia-Webface seems to perform slightly better in terms of tighter clusters.
#
# 2. Performance Impact of Noise Transformations
# The effect of noise transformations is clearly visible:
#
# Noisy VGGFace2 (green dashed line) shows a significant increase in FAISS distances compared to the non-noisy version, indicating that VGGFace2 is relatively sensitive to noise. There are more extreme fluctuations, and the distances are consistently higher.
# Noisy Casia-Webface (red dashed line) also shows increased FAISS distances, but its performance is less affected compared to VGGFace2. The noisy Casia-Webface embeddings remain closer to the original non-noisy results, implying better noise robustness.
# Key takeaway: Both models experience performance degradation when noise is introduced, but Casia-Webface seems to be more resilient, showing less severe distance increases compared to VGGFace2.
#
# 3. Impact on System Design
# Based on the observations, here are some key takeaways for system design:
#
# Model Selection: Since Casia-Webface shows tighter clusters and is more resilient to noise, it might be a better choice for situations where noise or imperfect conditions are expected (e.g., real-world applications where probe images might not always be clean).
#
# Noise Handling: The significant impact of noise on both models suggests that some kind of noise reduction or preprocessing might be necessary before generating embeddings. For example, applying denoising algorithms or transformations before passing the images to the models could improve performance under noisy conditions.
#
# FAISS Search Parameters: The larger FAISS distances in VGGFace2 embeddings could lead to more false positives or errors in retrieval. For such a system, adjusting FAISS search parameters (like increasing the number of nearest neighbors k) might improve robustness, or filtering results based on distance thresholds could help mitigate the impact.
#
# Application Scenarios: If the system is intended for environments where the input images will be relatively clean (e.g., controlled conditions), VGGFace2 might still be suitable. However, if you expect the input images to have noise (e.g., from low-quality cameras or varying conditions), Casia-Webface would likely offer better performance.
#
# Conclusion:
# Casia-Webface provides generally better performance due to tighter clustering and better noise resilience.
# VGGFace2 may still be useful in clean, controlled environments, but it’s more affected by noise.
# For a robust system, denoising or preprocessing techniques and appropriate search thresholds will be crucial to handle noisy or degraded input images effectively.
